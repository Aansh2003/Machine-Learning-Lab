# %%
import numpy as np
import pandas as pd
import math

# %%
a = []
b = []
c = []
for i in range(0,100):
    a.append(np.random.randint(0,100))
    b.append(np.random.randint(0,100))
    c.append(np.random.randint(0,100))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
b = np.asarray(a)
df = pd.DataFrame({'first':a,'second':b,'third':c})
df
# Out:
#     first  second  third
# 0      96      96     99
# 1      99      99     82
# 2      29      29     68
# 3      35      35     29
# 4      83      83     50
# ..    ...     ...    ...
# 95     87      87     23
# 96     10      10     87
# 97     61      61     54
# 98     81      81     73
# 99     87      87     49
#
# [100 rows x 3 columns]

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.barplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar', stacked=True, color=['red', 'skyblue', 'green'])
# Out:
# <AxesSubplot:>

# %%
x = np.arange(0, 5*math.pi, 0.01)
y = np.sin(x)
plt.plot(x, y, color='green')
plt.show()

# %%
plt.axes(projection ="3d").scatter3D(a, b, c, color = "green")

# %%
x = np.outer(np.linspace(-3, 3, 32), np.ones(32))
y = x.copy().T
z = (np.sin(x **2) + np.cos(y **2) )

plt.axes(projection ="3d").plot_surface(x,y,z,color='green')

# %%
sns.violinplot(b)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
plt.pie([10,20,30,40],autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2711dcd0100>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-1.0461621902025062, 0.3399186252483017, ''),
#   Text(0.3399188211458418, -1.0461621265515308, '')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10%'),
#   Text(0.1854101859396479, 0.5706339132489631, '20%'),
#   Text(-0.5706339219286397, 0.18541015922634638, '30%'),
#   Text(0.18541026607955005, -0.5706338872099259, '40%')])

# %%
da = pd.read_csv("C:/Users/dsca/Downloads/mtcars (1).csv")
da
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
sns.histplot(da['hp'])
# Out:
# <AxesSubplot:xlabel='hp', ylabel='Count'>

# %%
sns.boxplot(da['mpg'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %%
c = sns.boxplot(da.loc[da['am']==1]['mpg'])
d = sns.boxplot(da.loc[da['am']==0]['mpg'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
db = pd.read_csv("C:/Users/dsca/Downloads/cereal (1).csv")
db
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
e = sns.boxplot(db.loc[db['type']=='C']['calories'])
f = sns.boxplot(db.loc[db['type']=='H']['calories'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
column = False
for columns in db:
    if columns == 'calories':
        column = True
    if column:
        print(columns)
        sns.boxplot(db[columns])
        plt.plot()
# Out:
# calories
# protein
# fat
# sodium
# fiber
# carbo
# sugars
# potass
# vitamins
# shelf
# weight
# cups
# rating
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
cs = []
ec = []
ee = []
ic = []
for i in range(0,10):
    cs.append(np.random.randint(0,100))
    ec.append(np.random.randint(0,100))
    ee.append(np.random.randint(0,100))
    ic.append(np.random.randint(0,100))

# %%
dicti = {'cse':cs,'ece':ec,'eee':ee,'ict':ic}
dataframe = pd.DataFrame(dicti)
dataframe
# Out:
#    cse  ece  eee  ict
# 0   68   14   38   38
# 1   83   36   74   12
# 2   56   25   40    6
# 3   64   71   65   28
# 4   57   63   61   21
# 5   85   53   78   91
# 6   75   97   10   61
# 7    0   92   60   54
# 8   27    3   65    4
# 9   68   54   32   69

# %%
dataframe.plot()
# Out:
# <AxesSubplot:>

# %%
a = np.random.rand(3,3)
a
# Out:
# array([[0.14524149, 0.95324336, 0.1374408 ],
#        [0.70536536, 0.82448408, 0.72257939],
#        [0.39707338, 0.11393555, 0.07601758]])

# %%
a.transpose()
# Out:
# array([[0.14524149, 0.70536536, 0.39707338],
#        [0.95324336, 0.82448408, 0.11393555],
#        [0.1374408 , 0.72257939, 0.07601758]])

# %%
np.linalg.inv(a.transpose())
# Out:
# array([[-0.10589351,  1.25709237, -1.33100811],
#        [-0.30608082, -0.23457333,  1.95037501],
#        [ 3.1008851 , -0.04312066, -2.97781071]])

# %%
b = np.random.rand(3,3)
print(a*b)
# Out:
# [[0.12714254 0.28334026 0.12024307]
#  [0.03443863 0.37164014 0.15189606]
#  [0.34522162 0.04247846 0.00186027]]
