# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
col_names = ['species', 'island', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex', 'year' ]
pima = pd.read_csv("D:/210968186/penguins.csv", names=col_names)
pima = pima[1:].dropna()
pima = pima.replace(to_replace={'male':1,'female':0})
pima
# Out:
#          species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 1.0       Adelie  Torgersen           39.1          18.7               181
# 2.0       Adelie  Torgersen           39.5          17.4               186
# 3.0       Adelie  Torgersen           40.3            18               195
# 5.0       Adelie  Torgersen           36.7          19.3               193
# 6.0       Adelie  Torgersen           39.3          20.6               190
# ...          ...        ...            ...           ...               ...
# 340.0  Chinstrap      Dream           55.8          19.8               207
# 341.0  Chinstrap      Dream           43.5          18.1               202
# 342.0  Chinstrap      Dream           49.6          18.2               193
# 343.0  Chinstrap      Dream           50.8            19               210
# 344.0  Chinstrap      Dream           50.2          18.7               198
#
#       body_mass_g  sex  year
# 1.0          3750    1  2007
# ...

# %%
X = pima.drop(['body_mass_g','species','island'],axis=1)
Y = pima['body_mass_g']
#y = pima.label 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeRegressor()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print("R2:",metrics.r2_score(y_test, y_pred))
# Out:
# R2: 0.6569578425301994
